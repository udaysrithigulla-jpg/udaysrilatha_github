# %%
# !pip install numpy
# !pip install pandas

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\udaysri\\Downloads\\archive (2)\\hospital_patients.csv",delimiter=',')
data
# Out:
#      Patient_ID  Age  Gender     Diagnosis  Admitted
# 0             1   63    Male           Flu         1
# 1             2   46  Female          Cold         0
# 2             3   34  Female      Diabetes         0
# 3             4   67    Male           Flu         1
# 4             5   65  Female          Cold         0
# ..          ...  ...     ...           ...       ...
# 495         496   30    Male  Hypertension         1
# 496         497   19  Female      Diabetes         1
# 497         498   97  Female           Flu         0
# 498         499   25    Male          Cold         1
# 499         500   77    Male  Hypertension         0
#
# [500 rows x 5 columns]

# %%
data.head()
# Out:
#    Patient_ID  Age  Gender Diagnosis  Admitted
# 0           1   63    Male       Flu         1
# 1           2   46  Female      Cold         0
# 2           3   34  Female  Diabetes         0
# 3           4   67    Male       Flu         1
# 4           5   65  Female      Cold         0

# %%
data.tail()
# Out:
#      Patient_ID  Age  Gender     Diagnosis  Admitted
# 495         496   30    Male  Hypertension         1
# 496         497   19  Female      Diabetes         1
# 497         498   97  Female           Flu         0
# 498         499   25    Male          Cold         1
# 499         500   77    Male  Hypertension         0

# %%
data.isnull().sum()
# Out:
# Patient_ID    0
# Age           0
# Gender        0
# Diagnosis     0
# Admitted      0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Patient_ID    0
# Age           0
# Gender        0
# Diagnosis     0
# Admitted      0
# dtype: int64

# %%
data
# Out:
#      Patient_ID  Age  Gender     Diagnosis  Admitted
# 0             1   63    Male           Flu         1
# 1             2   46  Female          Cold         0
# 2             3   34  Female      Diabetes         0
# 3             4   67    Male           Flu         1
# 4             5   65  Female          Cold         0
# ..          ...  ...     ...           ...       ...
# 495         496   30    Male  Hypertension         1
# 496         497   19  Female      Diabetes         1
# 497         498   97  Female           Flu         0
# 498         499   25    Male          Cold         1
# 499         500   77    Male  Hypertension         0
#
# [500 rows x 5 columns]

# %%
data['Gender'].values
# Out:
# array(['Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male',
#        'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male',
#        'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male',
#        'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female',
#        'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female',
#        'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female',
#        'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male',
# ...

# %%
data=data.replace('Age','Admited',regex=True)
data.head()
# Out:
#    Patient_ID  Age  Gender Diagnosis  Admitted
# 0           1   63    Male       Flu         1
# 1           2   46  Female      Cold         0
# 2           3   34  Female  Diabetes         0
# 3           4   67    Male       Flu         1
# 4           5   65  Female      Cold         0

# %%
data
# Out:
#      Patient_ID  Age  Gender     Diagnosis  Admitted
# 0             1   63    Male           Flu         1
# 1             2   46  Female          Cold         0
# 2             3   34  Female      Diabetes         0
# 3             4   67    Male           Flu         1
# 4             5   65  Female          Cold         0
# ..          ...  ...     ...           ...       ...
# 495         496   30    Male  Hypertension         1
# 496         497   19  Female      Diabetes         1
# 497         498   97  Female           Flu         0
# 498         499   25    Male          Cold         1
# 499         500   77    Male  Hypertension         0
#
# [500 rows x 5 columns]

# %%
plt.bar(data['Gender'],data['Diagnosis'],color='yellow')
plt.title('Diagnosis')
plt.ylabel('Diagnosis')
plt.gcf().set_size_inches(2,4)
plt.xticks(rotation=70)
plt.show()

# %%
data['Age']
# Out:
# 0      63
# 1      46
# 2      34
# 3      67
# 4      65
#        ..
# 495    30
# 496    19
# 497    97
# 498    25
# 499    77
# Name: Age, Length: 500, dtype: int64
